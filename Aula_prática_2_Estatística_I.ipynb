# %%
# Gerando uma amostra de valores aleatórios para nossa distribuição uniforme

import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import uniform
import statistics as st
import numpy as np


a = -1
b = 1
amostra = 1000
x_uniforme = np.random.uniform(a, b, amostra)
plt.figure(figsize=(10,6))
plt.subplot(211)
plt.plot(x_uniforme, color = 'black')
plt.xlabel('eixo horizontal')
plt.ylabel('Números aleatórios entre -1 e 1')

plt.subplot(212)
plt.hist(x_uniforme, bins=5)
plt.xlabel('Classes')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
# Função densidade de probabilidade

x1 = np.linspace(-2, 2, 100)
y1 = uniform.pdf(x1)
plt.figure(figsize=(10,6))
plt.plot(x1, y1)

# %%
# Função distribuição acumulada

y = uniform.cdf(x1)
plt.figure(figsize=(10,6))
plt.plot(x1,y)

# %%
# Média da distribuição

med_dados = st.mean(x_uniforme)
med_teorica = (a + b)/2

# Variância

var_dados = st.pvariance(x_uniforme)
var_teorica = ((b-a)**2)/12

# Calculando uma função dos dados

a_cal = med_dados*2 -( med_dados*2+np.sqrt(var_dados*12)/2)
b_cal = a_cal +np.sqrt(var_dados*12)

print(med_dados, med_teorica)
print(var_dados, var_teorica)
print(a_cal,b_cal)
# Out:
# -0.005109572682608961 0.0
# 0.32751143774919395 0.3333333333333333
# -0.9912286886725897 0.9912286886725897

# %%
# Exemplo: Considere a v.a K for uniformemente distribuida em [0,5], qual será a probabilidade de que as raízes da equação abaixo sejam reais? 4x2+4Kx+K+2=0

p1 = uniform.cdf(-1, 0, 5)
p2 = 1- uniform.cdf(2, 0, 5)
p = p1+p2
p
# Out:
# 0.6

# %%
plt.figure(figsize=(10,6))
# define os valores de x
mean = 0
sigma = 2
x = np.linspace(-10,20,200)
pdf = norm.pdf(x,mean,sigma)
plt.plot(x,pdf , color = 'red', label=r'$\mu=0, \sigma =2$')

# define os valores de x
mean = 8
sigma = 2
pdf = norm.pdf(x,mean,sigma)
plt.plot(x,pdf , color = 'blue', label=r'$\mu=8, \sigma =2$')


#Plotting the Results
plt.xlabel('x',fontsize = 20)
plt.ylabel('f(x)',fontsize = 20)
plt.legend(fontsize = 15)
#plt.savefig('normal.svg')
plt.show()

# %%
plt.figure(figsize=(10,6))
# define os valores de x
mean = 0
sigma = 2
x = np.linspace(-15,15,200)
pdf = norm.pdf(x,mean,sigma)
plt.plot(x,pdf , color = 'red', label=r'$\mu=0, \sigma =2$')

# define os valores de x
mean = 0
sigma = 4
pdf = norm.pdf(x,mean,sigma)
plt.plot(x,pdf , color = 'blue', label=r'$\mu=0, \sigma =4$')


plt.xlabel('x',fontsize = 20)
plt.ylabel('f(x)',fontsize = 20)
plt.legend(fontsize = 15)
plt.show()

# %%
mean = 0
sigma = 10
n = 1000
x_normal = np.random.normal(mean, sigma, n)
plt.figure(figsize=(10,6))
plt.plot(x_normal, color = 'black')
plt.plot(x_uniforme, color = 'red') # Construindo um gráfico da distribuição uniforme em relação à normal
plt.figure(figsize=(10,6))
Pk, bins, ignored = plt.hist(x_normal, bins='auto', density=True, color='#0504aa',alpha=0.7,
                                rwidth=0.9)

# define os valores de x
x = np.linspace(np.min(x_normal),np.max(x_normal),200)

# Distribuicao teorica
pdf = norm.pdf(x,mean,sigma)

plt.plot(x,pdf , color = 'red')
plt.xlabel('Data points')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %%
# Aproximando uma distribuição binomial para uma normal

from random import seed
from scipy.stats import binom
seed(100) # semente do gerador de números aleatórios

n = 100 # numero de lançamentos
p = 0.05 # probabilidade de sair cara
vk = np.arange(0,n)
Pk = [binom.pmf(k, n, p) for k in vk]

plt.figure(figsize=(10,6))
plt.bar(vk, Pk, label='Simulacao')

# curva normal
x = np.linspace(0,n,200)
mean = n*p
sigma = np.sqrt(n*(1-p)*p)
pdf = norm.pdf(x,mean,sigma)
plt.plot(x, pdf, 'r--', label='Prob. Teórica')
plt.xlabel('k', fontsize = 20)
plt.ylabel('P(k)',fontsize = 20)
plt.legend(fontsize = 15)
plt.show(True)
